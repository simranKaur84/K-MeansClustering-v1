# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes = True)
import matplotlib.pyplot as plt
import nltk
#nltk.download('punkt')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples

# %% [markdown]
# # Exploratory Data Analysis / Feature Engineering

# %%
# read the csv file using pandas
data = pd.read_csv("problem_statement_7.csv")

# %%
# Let's see the first five rows of the data using head() function.
data.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
# let's see the last five rows the data using tail() function.
data.tail()
# Out:
#                                                   Review  Rating
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2

# %%
# let's see the data dimensions
data.shape
# Out:
# (20491, 2)

# %%
# Let's try to describe the data statistics by using the Describe function.
data.describe()
# Out:
#              Rating
# count  20491.000000
# mean       3.952223
# std        1.233030
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
# let's see the data type of every column present in our data.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 320.3+ KB

# %%
# Now, we will check if there are any null values present in the dataset.
# if any of the missing values will be present in dataset, we will remove those values.
data.isnull().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %%
# After the null results above, we can conclude that we don't have any missing values in our data.
# So, we don't have to remove any values containing the missing values.
# Now, let's visualise our reviews present in the datset using the bar chart.
# value_counts() function provides us all the reviews present in our dataset with their frequencies.
# Those frequencies can be then ordered ascending and selecting only top 5 out of those.
rating_counts = data['Rating'].value_counts().sort_values(ascending=False).iloc[0:5]

# %%
plt.figure(figsize=(14,6))
sns.barplot(rating_counts.index, rating_counts.index, palette=sns.cubehelix_palette(start=2.8, rot=.1,n_colors=10))
plt.ylabel("Count")
plt.title("Top 10 Rating");
plt.xticks(rotation=90);
# Out:
# C:\Users\kaurs\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Convert all text to Lower Case - Preprocessing

# %%
# Converting all the text to lower case.
data['Review'] = data['Review'].str.lower()

# %% [markdown]
# ## Tokenization - Preprocessing

# %%
# let's iterate through every row in the dataset.
# We have to remove the stopwords from the data as these words need not be included 
# and are useless words which only increase the cost and the valuable processing time.
# Let's first start with the tokenization process..
# the tokenization process is to split the text into the words or sentences.
# we will use NLTK library to achieve this.
# let's just apply this to the first row only and see the output.
print(nltk.word_tokenize(data['Review'][0]))
# Out:
# ['nice', 'hotel', 'expensive', 'parking', 'got', 'good', 'deal', 'stay', 'hotel', 'anniversary', ',', 'arrived', 'late', 'evening', 'took', 'advice', 'previous', 'reviews', 'did', 'valet', 'parking', ',', 'check', 'quick', 'easy', ',', 'little', 'disappointed', 'non-existent', 'view', 'room', 'room', 'clean', 'nice', 'size', ',', 'bed', 'comfortable', 'woke', 'stiff', 'neck', 'high', 'pillows', ',', 'not', 'soundproof', 'like', 'heard', 'music', 'room', 'night', 'morning', 'loud', 'bangs', 'doors', 'opening', 'closing', 'hear', 'people', 'talking', 'hallway', ',', 'maybe', 'just', 'noisy', 'neighbors', ',', 'aveda', 'bath', 'products', 'nice', ',', 'did', 'not', 'goldfish', 'stay', 'nice', 'touch', 'taken', 'advantage', 'staying', 'longer', ',', 'location', 'great', 'walking', 'distance', 'shopping', ',', 'overall', 'nice', 'experience', 'having', 'pay', '40', 'parking', 'night', ',']

# %%
# Now, we will apply word_tokenize() to all the records.
# let's create a function which will take the row as a parameter
# and will tokenize all the words present in it.
# Here we will also strip out non alphanumeric words/characters (such as numbers and punctuation) 
# using .isalpha (you could use .isalnum if you wanted to keep in numbers as well)
def identify_tokens(row):
    review = row['Review']
    tokens = nltk.word_tokenize(review)
    token_words = [word for word in tokens if word.isalpha()]
    return token_words

# %%
# Now, we have created a function that will take each row as a parameter
# and will remove all the punctuations(unnecessary) and numbers from the dataset.
# let's iterate over the dataset and pass each row of the data from the function defined above.
data['Review'] = data.apply(identify_tokens, axis = 1)

# %%
# Now, that we have applied the created function to remove the punctuations and the numbers from the dataset
# we will again have a look on the first row of the dataset as we did earlier to see the difference.
print(data['Review'][0])
# Out:
# ['nice', 'hotel', 'expensive', 'parking', 'got', 'good', 'deal', 'stay', 'hotel', 'anniversary', 'arrived', 'late', 'evening', 'took', 'advice', 'previous', 'reviews', 'did', 'valet', 'parking', 'check', 'quick', 'easy', 'little', 'disappointed', 'view', 'room', 'room', 'clean', 'nice', 'size', 'bed', 'comfortable', 'woke', 'stiff', 'neck', 'high', 'pillows', 'not', 'soundproof', 'like', 'heard', 'music', 'room', 'night', 'morning', 'loud', 'bangs', 'doors', 'opening', 'closing', 'hear', 'people', 'talking', 'hallway', 'maybe', 'just', 'noisy', 'neighbors', 'aveda', 'bath', 'products', 'nice', 'did', 'not', 'goldfish', 'stay', 'nice', 'touch', 'taken', 'advantage', 'staying', 'longer', 'location', 'great', 'walking', 'distance', 'shopping', 'overall', 'nice', 'experience', 'having', 'pay', 'parking', 'night']

# %%
# As we can see that we have removed the punctuation marks and the numbers from dataset.
# similarly, All other rows would have got the extra marks removed.
# Now, Let's perform stemming.

# %% [markdown]
# ## Stemming

# %%
# Stemming reduces the related words to the common stem.It is an optional process step.
# Let's perform stemming.
# For example, if we have three words such as 'frightening', 'frighten', 'frightened'
# it reduces all the three words to 'frighten' , 'frighten', 'frighten'.
stemming = PorterStemmer()

# %%
# Let's create a function to apply stemming to all the rows of the dataset.
def stem_list(row):
    review_list = row['Review']
    stemmed_list = [stemming.stem(word) for word in review_list]
    return stemmed_list

# %%
# Now that we have created the function for stemming..
# we will pass each row of the dataset from this function.
data['Review'] = data.apply(stem_list, axis =1)

# %%
# let's observe the first row of the dataset after stemming
print(data['Review'][0])
# Out:
# ['nice', 'hotel', 'expens', 'park', 'got', 'good', 'deal', 'stay', 'hotel', 'anniversari', 'arriv', 'late', 'even', 'took', 'advic', 'previou', 'review', 'did', 'valet', 'park', 'check', 'quick', 'easi', 'littl', 'disappoint', 'view', 'room', 'room', 'clean', 'nice', 'size', 'bed', 'comfort', 'woke', 'stiff', 'neck', 'high', 'pillow', 'not', 'soundproof', 'like', 'heard', 'music', 'room', 'night', 'morn', 'loud', 'bang', 'door', 'open', 'close', 'hear', 'peopl', 'talk', 'hallway', 'mayb', 'just', 'noisi', 'neighbor', 'aveda', 'bath', 'product', 'nice', 'did', 'not', 'goldfish', 'stay', 'nice', 'touch', 'taken', 'advantag', 'stay', 'longer', 'locat', 'great', 'walk', 'distanc', 'shop', 'overal', 'nice', 'experi', 'have', 'pay', 'park', 'night']

# %%
# Let's remove the stop words from the dataset now.

# %% [markdown]
# ## Remove Stopwords - Preprocessing

# %%
# let's define the function to remove the stopwords from the dataset.
# the stopwords are some useless words that should be removed because 
# processing of the useless words increase the cost and the valuable processing time.
stops = set(stopwords.words("english"))                  
def remove_stopwords(row):
    stemmed_list = row['Review']
    meaningful_words = [word for word in stemmed_list if not word in stops]
    return meaningful_words

# %%
# Here, we will pass all the rows of our dataset from the function created above.
# It would remove all the stop words from the dataset.
# Hence, saving our cost and valuable processing time.
data['Review'] = data.apply(remove_stopwords, axis=1)

# %%
# Now that we have removed the stopwords from our dataset.
# we will have a look at the first row to observe the results.
print(data['Review'][0])
# Out:
# ['nice', 'hotel', 'expens', 'park', 'got', 'good', 'deal', 'stay', 'hotel', 'anniversari', 'arriv', 'late', 'even', 'took', 'advic', 'previou', 'review', 'valet', 'park', 'check', 'quick', 'easi', 'littl', 'disappoint', 'view', 'room', 'room', 'clean', 'nice', 'size', 'bed', 'comfort', 'woke', 'stiff', 'neck', 'high', 'pillow', 'soundproof', 'like', 'heard', 'music', 'room', 'night', 'morn', 'loud', 'bang', 'door', 'open', 'close', 'hear', 'peopl', 'talk', 'hallway', 'mayb', 'noisi', 'neighbor', 'aveda', 'bath', 'product', 'nice', 'goldfish', 'stay', 'nice', 'touch', 'taken', 'advantag', 'stay', 'longer', 'locat', 'great', 'walk', 'distanc', 'shop', 'overal', 'nice', 'experi', 'pay', 'park', 'night']

# %%
# The results above show that the stopwords have been removed from the dataset.

# %% [markdown]
# ## Rejoin Words - Preprocessing

# %%
# let's now define a function that will rejoin all the processed words.
def rejoin_words(row):
    review_list = row['Review']
    joined_list = (" ".join(review_list))
    return joined_list

# %%
# Now that we have created the function that will return us the 
# words after joining. We will be getting the preprocessed words.
data['Review'] = data.apply(rejoin_words, axis=1)

# %%
# We have rejoined the words, let's observe the first row.
print(data['Review'][0])
# Out:
# nice hotel expens park got good deal stay hotel anniversari arriv late even took advic previou review valet park check quick easi littl disappoint view room room clean nice size bed comfort woke stiff neck high pillow soundproof like heard music room night morn loud bang door open close hear peopl talk hallway mayb noisi neighbor aveda bath product nice goldfish stay nice touch taken advantag stay longer locat great walk distanc shop overal nice experi pay park night

# %%
# Now, we can easily read and understand the above text.
# But it is difficult for the computer to understand the sentence.
# As computers, can only understand the numerical value.
# for this reason, we vectorize all text so that computer can understand better.
# TF-IDF = Term Frequency (TF) * Inverse Document Frequency (IDF)

# %% [markdown]
# ## Calculating TF-IDF - Preprocessing

# %%
# Now, we have to reduce the TF-IDF vector to the two dimensions using PCA.
# Tokenize and generate count vectors
word_vec = data['Review'].apply(str.split).apply(pd.value_counts).fillna(0)

# Compute term frequencies
tf = word_vec.divide(np.sum(word_vec, axis=1), axis=0)

# Compute inverse document frequencies
idf = np.log10(len(tf) / word_vec[word_vec > 0].count()) 

# Compute TF-IDF vectors
tfidf = np.multiply(tf, idf.to_frame().T)

# %%
print(tfidf)
# Out:
#            nice      room      park      stay     night     hotel  \
# 0      0.026910  0.002879  0.038243  0.005377  0.009307  0.002279
# 1      0.001898  0.002031  0.000000  0.000632  0.003282  0.002813
# 2      0.006970  0.003728  0.000000  0.003095  0.010044  0.001476
# 3      0.010370  0.000924  0.000000  0.003454  0.000000  0.004391
# 4      0.000000  0.000887  0.005889  0.001656  0.000000  0.001579
# ...         ...       ...       ...       ...       ...       ...
# 20486  0.004295  0.000766  0.020345  0.004291  0.000000  0.000000
# 20487  0.012148  0.000000  0.028774  0.000000  0.000000  0.005144
# 20488  0.007331  0.003921  0.017363  0.000000  0.000000  0.003104
# 20489  0.000000  0.001941  0.001433  0.001208  0.002615  0.004610
# 20490  0.000000  0.000913  0.000000  0.003412  0.008858  0.003254
#
#        anniversari    review     touch  advantag  ...  blackmail  aftermath  \
# 0         0.022533  0.008929  0.017374  0.022747  ...   0.000000   0.000000
# 1         0.015894  0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 2         0.000000  0.000000  0.007500  0.000000  ...   0.000000   0.000000
# 3         0.000000  0.000000  0.016738  0.000000  ...   0.000000   0.000000
# 4         0.000000  0.000000  0.000000  0.000000  ...   0.000000   0.000000
# ...            ...       ...       ...       ...  ...        ...        ...
# 20486     0.000000  0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 20487     0.000000  0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 20488     0.000000  0.000000  0.000000  0.000000  ...   0.000000   0.000000
# 20489     0.000000  0.000000  0.000000  0.000000  ...   0.006133   0.006133
# 20490     0.000000  0.000000  0.000000  0.000000  ...   0.000000   0.000000
#
#        moneybelt      elus  barcelonin     mosso    unbolt      evas  \
# 0       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 1       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 2       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 3       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 4       0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# ...          ...       ...         ...       ...       ...       ...
# 20486   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 20487   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 20488   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
# 20489   0.006133  0.006133    0.006133  0.006133  0.006133  0.006133
# 20490   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000
#
#        undercov  indemnifi
# 0      0.000000   0.000000
# 1      0.000000   0.000000
# 2      0.000000   0.000000
# 3      0.000000   0.000000
# 4      0.000000   0.000000
# ...         ...        ...
# 20486  0.000000   0.000000
# 20487  0.000000   0.000000
# 20488  0.000000   0.000000
# 20489  0.006133   0.006133
# 20490  0.000000   0.000000
#
# [20491 rows x 34386 columns]

# %%
# reduce the tf-idf vectors to two dimensions using PCA. 
reduced_data = PCA(n_components=2).fit_transform(tfidf)

# %%
# let's see the results after applying the PCA.
print(reduced_data)
# Out:
# [[-0.00606541 -0.01950294]
#  [ 0.00420211 -0.01792358]
#  [ 0.0031204  -0.01509582]
#  ...
#  [-0.00437851 -0.01736139]
#  [ 0.00375064 -0.01045425]
#  [-0.0003956  -0.00679927]]

# %% [markdown]
# # K-Means Clustering

# %%
# lets see the data and the reduced data.
data.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expens park got good deal stay hote...       4
# 1  ok noth special charg diamond member hilton de...       2
# 2  nice room experi hotel monaco seattl good hote...       3
# 3  uniqu great stay wonder time hotel monaco loca...       5
# 4  great stay great stay went seahawk game awesom...       5

# %%
reduced_data
# Out:
# array([[-0.00606541, -0.01950294],
#        [ 0.00420211, -0.01792358],
#        [ 0.0031204 , -0.01509582],
#        ...,
#        [-0.00437851, -0.01736139],
#        [ 0.00375064, -0.01045425],
#        [-0.0003956 , -0.00679927]])

# %%
kmeans_pca = KMeans(n_clusters = 2, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
reduced_data.shape
# Out:
# (20491, 2)

# %%
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)

# %%
#filter rows of original data
filtered_label0 = reduced_data[label == 0]
 
#plotting the results
plt.scatter(filtered_label0[:,0] , filtered_label0[:,1])
plt.show()

# %%
print(label)
# Out:
# [0 0 0 ... 0 0 0]

# %%
u_labels = np.unique(label)

# %%
print(u_labels)
# Out:
# [0 1]

# %%
#filter rows of original data
filtered_label0 = reduced_data[label == 1]

#plotting the results
plt.scatter(filtered_label0[:,0] , filtered_label0[:,1])
plt.show()

# %% [markdown]
# ## Cluster - 3

# %%
kmeans_pca = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)
u_labels = np.unique(label)
silhouette_scores=[]    

# Getting the centroids
centroids = kmeans_pca.cluster_centers_
for i in u_labels:
    plt.scatter(reduced_data[label == i , 0] , reduced_data[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.show()

num_clusters = 3
sample_silhouette_values = silhouette_samples(reduced_data, label)
score_for_3 = silhouette_score(reduced_data, kmeans_pca.labels_, metric='euclidean')
# Print the score
print('Silhouette Score: %.3f' % score_for_3)
silhouette_scores.append(score_for_3)

means_lst = []
for label in range(num_clusters):
    means_lst.append(sample_silhouette_values[kmeans_pca.labels_ == label].mean())
print(means_lst)
# Out:
# Silhouette Score: 0.402
# [0.34877764440162196, 0.45474624661814833, 0.41924155096842336]

# %% [markdown]
# ##  Cluster - 4

# %%
kmeans_pca = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)
u_labels = np.unique(label)

# Getting the centroids
centroids = kmeans_pca.cluster_centers_
for i in u_labels:
    plt.scatter(reduced_data[label == i , 0] , reduced_data[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.show()

num_clusters = 4
sample_silhouette_values = silhouette_samples(reduced_data, label)
score_for_4 = silhouette_score(reduced_data, kmeans_pca.labels_, metric='euclidean')
# Print the score
print('Silhouette Score: %.3f' % score_for_4)
silhouette_scores.append(score_for_4)
means_lst = []
for label in range(num_clusters):
    means_lst.append(sample_silhouette_values[kmeans_pca.labels_ == label].mean())
print(means_lst)
# Out:
# Silhouette Score: 0.360
# [0.34569730900552853, 0.4448426994297667, 0.3610831806237167, 0.2819124818176725]

# %% [markdown]
# ## Cluster - 5

# %%
kmeans_pca = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)
u_labels = np.unique(label)

# Getting the centroids
centroids = kmeans_pca.cluster_centers_
for i in u_labels:
    plt.scatter(reduced_data[label == i , 0] , reduced_data[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.show()

num_clusters = 5
sample_silhouette_values = silhouette_samples(reduced_data, label)
score_for_5 = silhouette_score(reduced_data, kmeans_pca.labels_, metric='euclidean')
# Print the score
print('Silhouette Score: %.3f' % score_for_5)
silhouette_scores.append(score_for_5)
means_lst = []
for label in range(num_clusters):
    means_lst.append(sample_silhouette_values[kmeans_pca.labels_ == label].mean())
print(means_lst)
# Out:
# Silhouette Score: 0.343
# [0.2983027792170289, 0.385150193962006, 0.3463860422964467, 0.27674945408117835, 0.3527257437098951]

# %% [markdown]
# ## Cluster - 6

# %%
kmeans_pca = KMeans(n_clusters = 6, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)
u_labels = np.unique(label)

# Getting the centroids
centroids = kmeans_pca.cluster_centers_
for i in u_labels:
    plt.scatter(reduced_data[label == i , 0] , reduced_data[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.show()

num_clusters = 6
sample_silhouette_values = silhouette_samples(reduced_data, label)
score_for_6 = silhouette_score(reduced_data, kmeans_pca.labels_, metric='euclidean')
# Print the score
print('Silhouette Score: %.3f' % score_for_6)
silhouette_scores.append(score_for_6)
means_lst = []
for label in range(num_clusters):
    means_lst.append(sample_silhouette_values[kmeans_pca.labels_ == label].mean())
print(means_lst)
# Out:
# Silhouette Score: 0.347
# [0.2985511489282858, 0.3821679312244012, 0.2712631694022512, 0.29673610217312696, 0.34397759606392625, 0.43593112074049273]

# %% [markdown]
# ## Cluster - 7

# %%
kmeans_pca = KMeans(n_clusters = 7, init = 'k-means++', random_state = 42)
kmeans_pca.fit(reduced_data)
#predict the labels of clusters.
label = kmeans_pca.fit_predict(reduced_data)
u_labels = np.unique(label)

# Getting the centroids
centroids = kmeans_pca.cluster_centers_
for i in u_labels:
    plt.scatter(reduced_data[label == i , 0] , reduced_data[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.show()

num_clusters = 7
sample_silhouette_values = silhouette_samples(reduced_data, label)
score_for_7 = silhouette_score(reduced_data, kmeans_pca.labels_, metric='euclidean')
# Print the score
print('Silhouette Score: %.3f' % score_for_7)
silhouette_scores.append(score_for_7)
means_lst = []
for label in range(num_clusters):
    means_lst.append(sample_silhouette_values[kmeans_pca.labels_ == label].mean())
print(means_lst)
# Out:
# Silhouette Score: 0.336
# [0.35343687452410694, 0.2701815605333976, 0.33632242037624455, 0.28191562379295637, 0.28401949265409465, 0.43135615393792076, 0.3322815743930254]

# %%
print(silhouette_scores)
num_clusters=[3,4,5,6,7]
# Out:
# [0.4017790067916916, 0.3595433058689887, 0.3432273917223034, 0.34735591011749944, 0.3364998426905376]

# %%
# creating the bar plot
plt.bar(num_clusters, silhouette_scores, color ='maroon',
        width = 0.4)
 
plt.xlabel("Cluster Value")
plt.ylabel("Silhouette Scores")
plt.title("No. of Cluster vs Silhouette Scores")
plt.show()

# %%
data.shape
# Out:
# (20491, 2)

# %% [markdown]
# #### The value of 4  clusters looks to be the optimal one. The silhouette score for this cluster is above average silhouette scores. Also, the fluctuation in size is similar for the further increasing clusters

# %%
# The Apriori library we are going to use requires our dataset to be in the form of a list of lists, 
# where the whole dataset is a big list and each transaction in the dataset is an inner list within the 
# outer big list. 
records = []
for index in data.index:
    records.append(data['Review'][index].split(" "))
len(records)
# Out:
# 20491

# %%
pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\kaurs\anaconda3\lib\site-packages (1.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from apyori import apriori
association_rules = apriori(records, min_support=0.1, min_confidence=0.2,min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 2092

# %%
rule_len_2=0
list_of_confidence=[]
list_of_support=[]
for item in association_results:
    if len(item[0])==2:
        rule_len_2+=1
    # first index of the inner list
    # Contains base item and add item
        pair = item[0] 
        items = [x for x in pair]
        print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
        print("Support: " + str(item[1]))
        list_of_support.append(item[1]*100)

    #third index of the list located at 0th
    #of the third index of the inner list

        print("Confidence: " + str(item[2][0][2]))
        list_of_confidence.append(item[2][0][2]*100)
        print("Lift: " + str(item[2][0][3]))
        print("=====================================")
# Out:
# Rule: breakfast -> area
# Support: 0.10253281928651603
# Confidence: 0.4439983093829248
# Lift: 1.236137140973575
# =====================================
# Rule: area -> clean
# Support: 0.10712019911180519
# Confidence: 0.46386306001690625
# Lift: 1.1505892704038767
# =====================================
# Rule: day -> area
# Support: 0.10004392172173149
# Confidence: 0.43322062552831786
# Lift: 1.246261945486559
# =====================================
# Rule: area -> good
# Support: 0.12834903128202627
# Confidence: 0.5557903634826713
# Lift: 1.2207846862604157
# =====================================
# Rule: great -> area
# Support: 0.13762139475867455
# Confidence: 0.5959425190194422
# Lift: 1.1063107589443186
# =====================================
# Rule: hotel -> area
# Support: 0.19701332292225857
# Confidence: 0.8531276415891802
# Lift: 1.0496210449597052
# =====================================
# Rule: area -> locat
# Support: 0.11600214728417355
# Confidence: 0.5023245984784447
# Lift: 1.0796238040090005
# =====================================
# Rule: area -> nice
# Support: 0.11219559806744424
# Confidence: 0.48584108199492815
# Lift: 1.2932410510727557
# =====================================
# Rule: night -> area
# Support: 0.1183934410228881
# Confidence: 0.5126796280642435
# Lift: 1.1952802660899322
# =====================================
# Rule: room -> area
# Support: 0.2076033380508516
# Confidence: 0.2076033380508516
# Lift: 1.0
# =====================================
# Rule: staff -> area
# Support: 0.13449807232443511
# Confidence: 0.5824175824175825
# Lift: 1.0333638134313519
# =====================================
# Rule: stay -> area
# Support: 0.17632131179542238
# Confidence: 0.7635249366018597
# Lift: 1.0578356643616433
# =====================================
# Rule: walk -> area
# Support: 0.11053633302425456
# Confidence: 0.47865595942519024
# Lift: 1.40176350787217
# =====================================
# Rule: hotel -> arriv
# Support: 0.15021228832170222
# Confidence: 0.8386920980926431
# Lift: 1.0318606894035636
# =====================================
# Rule: room -> arriv
# Support: 0.16558489092772435
# Confidence: 0.9245231607629427
# Lift: 1.100842819872942
# =====================================
# Rule: staff -> arriv
# Support: 0.10663217998145527
# Confidence: 0.5953678474114441
# Lift: 1.0563410305054899
# =====================================
# Rule: stay -> arriv
# Support: 0.13649895075886975
# Confidence: 0.762125340599455
# Lift: 1.0558965756743361
# =====================================
# Rule: hotel -> ask
# Support: 0.13215558049875556
# Confidence: 0.8181268882175228
# Lift: 1.0065588752005559
# =====================================
# Rule: room -> ask
# Support: 0.14933385388707238
# Confidence: 0.9244712990936557
# Lift: 1.1007810674488987
# =====================================
# Rule: stay -> ask
# Support: 0.12371284954370211
# Confidence: 0.7658610271903323
# Lift: 1.0610722317888506
# =====================================
# Rule: away -> hotel
# Support: 0.13235078815089552
# Confidence: 0.8406695598264105
# Lift: 1.0342936025459608
# =====================================
# Rule: room -> away
# Support: 0.13981748084524914
# Confidence: 0.8880967141971483
# Lift: 1.0574693341050476
# =====================================
# Rule: stay -> away
# Support: 0.12381045336977209
# Confidence: 0.7864228146311222
# Lift: 1.0895598306021854
# =====================================
# Rule: day -> bar
# Support: 0.10028793128690644
# Confidence: 0.49661672305461574
# Lift: 1.4286358658026297
# =====================================
# Rule: good -> bar
# Support: 0.12180957493533746
# Confidence: 0.6031899468342194
# Lift: 1.3248971165805543
# =====================================
# Rule: great -> bar
# Support: 0.129715484847006
# Confidence: 0.6423392943450943
# Lift: 1.1924419714101584
# =====================================
# Rule: hotel -> bar
# Support: 0.16031428431994535
# Confidence: 0.7938617689705173
# Lift: 0.9767049839672693
# =====================================
# Rule: night -> bar
# Support: 0.10843785076374994
# Confidence: 0.5369743837602707
# Lift: 1.251921958997805
# =====================================
# Rule: restaur -> bar
# Support: 0.1053633302425455
# Confidence: 0.5217496375060415
# Lift: 1.6759949556570461
# =====================================
# Rule: room -> bar
# Support: 0.18178712605534136
# Confidence: 0.9001933301111649
# Lift: 1.0718729459764007
# =====================================
# Rule: staff -> bar
# Support: 0.12332243423942219
# Confidence: 0.610681488641856
# Lift: 1.0835115060836673
# =====================================
# Rule: stay -> bar
# Support: 0.14869942901761748
# Confidence: 0.736346060898985
# Lift: 1.0201803335957471
# =====================================
# Rule: bathroom -> bed
# Support: 0.10970670050265971
# Confidence: 0.45395799676898224
# Lift: 1.6658404927996444
# =====================================
# Rule: bathroom -> breakfast
# Support: 0.10824264311160997
# Confidence: 0.44789983844911146
# Lift: 1.2469994007691227
# =====================================
# Rule: bathroom -> clean
# Support: 0.11273241911082914
# Confidence: 0.4664781906300485
# Lift: 1.1570759719404822
# =====================================
# Rule: bathroom -> good
# Support: 0.1275682006734664
# Confidence: 0.5278675282714055
# Lift: 1.1594526231974884
# =====================================
# Rule: bathroom -> great
# Support: 0.135181299106925
# Confidence: 0.5593699515347335
# Lift: 1.0384172564684022
# =====================================
# Rule: bathroom -> hotel
# Support: 0.21175150065882584
# Confidence: 0.21175150065882584
# Lift: 1.0
# =====================================
# Rule: bathroom -> locat
# Support: 0.13122834415109072
# Confidence: 0.5430129240710824
# Lift: 1.167073403308218
# =====================================
# Rule: bathroom -> nice
# Support: 0.11439168415401883
# Confidence: 0.47334410339256866
# Lift: 1.2599758408180208
# =====================================
# Rule: bathroom -> night
# Support: 0.12586013371724172
# Confidence: 0.5207996768982229
# Lift: 1.2142116485745234
# =====================================
# Rule: bathroom -> room
# Support: 0.23058903909033235
# Confidence: 0.23058903909033235
# Lift: 1.0
# =====================================
# Rule: bathroom -> staff
# Support: 0.1383534234541994
# Confidence: 0.5724959612277868
# Lift: 1.0157602166004485
# =====================================
# Rule: bathroom -> stay
# Support: 0.1886193938802401
# Confidence: 0.7804927302100162
# Lift: 1.081343917155743
# =====================================
# Rule: bathroom -> walk
# Support: 0.10526572641647552
# Confidence: 0.4355815831987076
# Lift: 1.2756184395204684
# =====================================
# Rule: beach -> day
# Support: 0.11600214728417355
# Confidence: 0.5941014746313422
# Lift: 1.7090738897474145
# =====================================
# Rule: beach -> food
# Support: 0.1313747498901957
# Confidence: 0.6728317920519871
# Lift: 2.481460808304044
# =====================================
# Rule: beach -> good
# Support: 0.12068713093553267
# Confidence: 0.6180954761309673
# Lift: 1.357636874413083
# =====================================
# Rule: beach -> great
# Support: 0.12903225806451613
# Confidence: 0.6608347913021745
# Lift: 1.2267771071365154
# =====================================
# Rule: beach -> hotel
# Support: 0.12273681128300229
# Confidence: 0.6285928517870533
# Lift: 0.7733711273472536
# =====================================
# Rule: beach -> nice
# Support: 0.10253281928651603
# Confidence: 0.52511872031992
# Lift: 1.3977926342005043
# =====================================
# Rule: beach -> pool
# Support: 0.12224879215265239
# Confidence: 0.6260934766308422
# Lift: 2.949260098768411
# =====================================
# Rule: beach -> resort
# Support: 0.10726660485091015
# Confidence: 0.5493626593351661
# Lift: 3.8564543516399072
# =====================================
# Rule: beach -> restaur
# Support: 0.102728026938656
# Confidence: 0.5261184703824044
# Lift: 1.6900287782733736
# =====================================
# Rule: beach -> room
# Support: 0.1627543799716949
# Confidence: 0.8335416145963509
# Lift: 0.9925098044449896
# =====================================
# Rule: beach -> staff
# Support: 0.11356205163242399
# Confidence: 0.5816045988502874
# Lift: 1.0319213641909464
# =====================================
# Rule: beach -> stay
# Support: 0.13303401493338537
# Confidence: 0.6813296675831042
# Lift: 0.9439571479679099
# =====================================
# Rule: beach -> time
# Support: 0.1157093358059636
# Confidence: 0.5926018495376156
# Lift: 1.6582008055271449
# =====================================
# Rule: beauti -> great
# Support: 0.11375725928456396
# Confidence: 0.6281325788197251
# Lift: 1.166068551603097
# =====================================
# Rule: beauti -> hotel
# Support: 0.12942267336879607
# Confidence: 0.7146321746160065
# Lift: 0.8792271323960726
# =====================================
# Rule: room -> beauti
# Support: 0.15411644136450148
# Confidence: 0.8509835623821072
# Lift: 1.0132781786723086
# =====================================
# Rule: staff -> beauti
# Support: 0.11043872919818457
# Confidence: 0.6098086769064942
# Lift: 1.081962905748634
# =====================================
# Rule: stay -> beauti
# Support: 0.12761700258650138
# Confidence: 0.7046618162220425
# Lift: 0.9762829801356235
# =====================================
# Rule: breakfast -> bed
# Support: 0.1151725147625787
# Confidence: 0.42263610315186245
# Lift: 1.1766625529463062
# =====================================
# Rule: bed -> clean
# Support: 0.12239519789175736
# Confidence: 0.4491404011461318
# Lift: 1.1140704466632838
# =====================================
# Rule: bed -> comfort
# Support: 0.10575374554682544
# Confidence: 0.3880730659025788
# Lift: 1.900120715271145
# =====================================
# Rule: day -> bed
# Support: 0.1124396076326192
# Confidence: 0.41260744985673353
# Lift: 1.186963253546866
# =====================================
# Rule: bed -> good
# Support: 0.14201356693182374
# Confidence: 0.5211318051575932
# Lift: 1.1446577145979464
# =====================================
# Rule: bed -> great
# Support: 0.15592211214679616
# Confidence: 0.5721704871060171
# Lift: 1.062180236572694
# =====================================
# Rule: bed -> hotel
# Support: 0.2318090869162071
# Confidence: 0.2318090869162071
# Lift: 1.0
# =====================================
# Rule: like -> bed
# Support: 0.10292323459079596
# Confidence: 0.3776862464183381
# Lift: 1.2976473634068018
# =====================================
# Rule: bed -> locat
# Support: 0.13601093162851985
# Confidence: 0.4991045845272206
# Lift: 1.0727031719684579
# =====================================
# Rule: bed -> nice
# Support: 0.1270313796300815
# Confidence: 0.46615329512893977
# Lift: 1.2408349143267219
# =====================================
# Rule: night -> bed
# Support: 0.145966521887658
# Confidence: 0.5356375358166189
# Lift: 1.2488051822071156
# =====================================
# Rule: room -> bed
# Support: 0.2544043726514079
# Confidence: 0.2544043726514079
# Lift: 1.0
# =====================================
# Rule: staff -> bed
# Support: 0.15475086623395637
# Confidence: 0.5678724928366762
# Lift: 1.0075569530449677
# =====================================
# Rule: stay -> bed
# Support: 0.2114586891806159
# Confidence: 0.2114586891806159
# Lift: 1.0
# =====================================
# Rule: bed -> time
# Support: 0.11209799424137426
# Confidence: 0.4113538681948424
# Lift: 1.1510381145951816
# =====================================
# Rule: walk -> bed
# Support: 0.11224439998047923
# Confidence: 0.41189111747851
# Lift: 1.2062399440120264
# =====================================
# Rule: good -> best
# Support: 0.10946269093748474
# Confidence: 0.5260318949343339
# Lift: 1.1554206837924146
# =====================================
# Rule: great -> best
# Support: 0.12546971841296178
# Confidence: 0.6029549718574109
# Lift: 1.1193287124778226
# =====================================
# Rule: hotel -> best
# Support: 0.16456005075398955
# Confidence: 0.7908067542213884
# Lift: 0.9729463344791636
# =====================================
# Rule: room -> best
# Support: 0.17641891562149237
# Confidence: 0.8477954971857411
# Lift: 1.0094821042961835
# =====================================
# Rule: staff -> best
# Support: 0.12327363232638719
# Confidence: 0.5924015009380863
# Lift: 1.0510779423086265
# =====================================
# Rule: stay -> best
# Support: 0.15641013127714606
# Confidence: 0.751641651031895
# Lift: 1.0413718100942906
# =====================================
# Rule: better -> hotel
# Support: 0.12590893563027672
# Confidence: 0.7933579335793358
# Lift: 0.9760851045916644
# =====================================
# Rule: better -> room
# Support: 0.14069591527987896
# Confidence: 0.886531365313653
# Lift: 1.0556054510222594
# =====================================
# Rule: better -> stay
# Support: 0.11858864867502807
# Confidence: 0.7472324723247232
# Lift: 1.0352630554703113
# =====================================
# Rule: room -> big
# Support: 0.10843785076374994
# Confidence: 0.9043549043549044
# Lift: 1.0768281913612845
# =====================================
# Rule: bit -> hotel
# Support: 0.12180957493533746
# Confidence: 0.8350618936099029
# Lift: 1.0273943717778757
# =====================================
# Rule: room -> bit
# Support: 0.13249719389000048
# Confidence: 0.908330545332887
# Lift: 1.0815620433735946
# =====================================
# Rule: stay -> bit
# Support: 0.11102435215460446
# Confidence: 0.7611241217798594
# Lift: 1.0545094238939214
# =====================================
# Rule: day -> book
# Support: 0.10497291493826558
# Confidence: 0.4572704081632653
# Lift: 1.3154468529655299
# =====================================
# Rule: book -> good
# Support: 0.11966229076179787
# Confidence: 0.5212585034013606
# Lift: 1.1449360052735855
# =====================================
# Rule: book -> great
# Support: 0.12820262554292128
# Confidence: 0.5584608843537415
# Lift: 1.0367296594756765
# =====================================
# Rule: book -> hotel
# Support: 0.19647650187887364
# Confidence: 0.8558673469387755
# Lift: 1.0529917626011678
# =====================================
# Rule: book -> locat
# Support: 0.1054609340686155
# Confidence: 0.45939625850340143
# Lift: 0.9873598419334172
# =====================================
# Rule: book -> night
# Support: 0.12337123615245718
# Confidence: 0.5374149659863946
# Lift: 1.2529491487117093
# =====================================
# Rule: room -> book
# Support: 0.2081401590942365
# Confidence: 0.2081401590942365
# Lift: 1.0
# =====================================
# Rule: staff -> book
# Support: 0.1372309794543946
# Confidence: 0.5977891156462585
# Lift: 1.0606370048235765
# =====================================
# Rule: stay -> book
# Support: 0.17183153579620322
# Confidence: 0.7485119047619049
# Lift: 1.037035661965936
# =====================================
# Rule: book -> time
# Support: 0.10306964032990093
# Confidence: 0.4489795918367347
# Lift: 1.2563212913186577
# =====================================
# Rule: breakfast -> clean
# Support: 0.1670489483187741
# Confidence: 0.4650815217391304
# Lift: 1.1536116041588818
# =====================================
# Rule: breakfast -> day
# Support: 0.14137914206236885
# Confidence: 0.3936141304347826
# Lift: 1.1323244625493654
# =====================================
# Rule: breakfast -> friendli
# Support: 0.11634376067541848
# Confidence: 0.3239130434782609
# Lift: 1.1255387780079777
# =====================================
# Rule: breakfast -> good
# Support: 0.19584207700941877
# Confidence: 0.5452445652173913
# Lift: 1.1976210082398504
# =====================================
# Rule: breakfast -> great
# Support: 0.20721292274657166
# Confidence: 0.20721292274657166
# Lift: 1.0
# =====================================
# Rule: breakfast -> help
# Support: 0.1378166024108145
# Confidence: 0.38369565217391305
# Lift: 1.1851533929297033
# =====================================
# Rule: breakfast -> hotel
# Support: 0.3115026109023474
# Confidence: 0.3115026109023474
# Lift: 1.0
# =====================================
# Rule: breakfast -> like
# Support: 0.11087794641549949
# Confidence: 0.30869565217391304
# Lift: 1.0606107660455486
# =====================================
# Rule: breakfast -> locat
# Support: 0.19442682153140403
# Confidence: 0.5413043478260869
# Lift: 1.1634012367636195
# =====================================
# Rule: breakfast -> nice
# Support: 0.15099311893026207
# Confidence: 0.4203804347826087
# Lift: 1.1189939580579937
# =====================================
# Rule: breakfast -> night
# Support: 0.17373481040456787
# Confidence: 0.4836956521739131
# Lift: 1.1277059516094725
# =====================================
# Rule: breakfast -> place
# Support: 0.11800302571860817
# Confidence: 0.3285326086956522
# Lift: 1.056325385969341
# =====================================
# Rule: breakfast -> recommend
# Support: 0.1086330584158899
# Confidence: 0.30244565217391306
# Lift: 1.1553717111662292
# =====================================
# Rule: breakfast -> restaur
# Support: 0.13069152310770582
# Confidence: 0.36385869565217394
# Lift: 1.1688083606535031
# =====================================
# Rule: breakfast -> room
# Support: 0.3227758528134303
# Confidence: 0.3227758528134303
# Lift: 1.0
# =====================================
# Rule: breakfast -> servic
# Support: 0.11424527841491386
# Confidence: 0.31807065217391306
# Lift: 1.0040957839617397
# =====================================
# Rule: breakfast -> small
# Support: 0.1049241130252306
# Confidence: 0.29211956521739135
# Lift: 1.2352088342694112
# =====================================
# Rule: breakfast -> staff
# Support: 0.21824215509247963
# Confidence: 0.21824215509247963
# Lift: 1.0
# =====================================
# Rule: breakfast -> stay
# Support: 0.2741691474305793
# Confidence: 0.2741691474305793
# Lift: 1.0
# =====================================
# Rule: breakfast -> time
# Support: 0.13225318432482552
# Confidence: 0.36820652173913043
# Lift: 1.030304497740888
# =====================================
# Rule: breakfast -> walk
# Support: 0.15240837440827681
# Confidence: 0.42432065217391307
# Lift: 1.2426403435323214
# =====================================
# Rule: room -> buffet
# Support: 0.12127275389195256
# Confidence: 0.9026516527424627
# Lift: 1.0748001055462726
# =====================================
# Rule: room -> busi
# Support: 0.10038553511297643
# Confidence: 0.8947368421052633
# Lift: 1.0653758284373844
# =====================================
# Rule: check -> hotel
# Support: 0.14230637841003368
# Confidence: 0.834096109839817
# Lift: 1.0262061475069162
# =====================================
# Rule: check -> room
# Support: 0.15855741545068566
# Confidence: 0.9293478260869565
# Lift: 1.1065876171972704
# =====================================
# Rule: check -> stay
# Support: 0.13327802449856035
# Confidence: 0.7811784897025172
# Lift: 1.0822940116628992
# =====================================
# Rule: hotel -> citi
# Support: 0.1368405641501147
# Confidence: 0.9244971974942302
# Lift: 1.137428524398335
# =====================================
# Rule: room -> citi
# Support: 0.13044751354253087
# Confidence: 0.8813056379821959
# Lift: 1.0493831034861512
# =====================================
# Rule: stay -> citi
# Support: 0.11361085354545898
# Confidence: 0.7675568743818002
# Lift: 1.0634217655819789
# =====================================
# Rule: day -> clean
# Support: 0.162071153189205
# Confidence: 0.40200944195617966
# Lift: 1.1564755685980734
# =====================================
# Rule: excel -> clean
# Support: 0.10062954467815138
# Confidence: 0.24960658515918172
# Lift: 1.0935831807775909
# =====================================
# Rule: food -> clean
# Support: 0.12088233858767264
# Confidence: 0.2998426340636727
# Lift: 1.1058451070192075
# =====================================
# Rule: friendli -> clean
# Support: 0.14176955736664879
# Confidence: 0.35165234233143694
# Lift: 1.2219277847572452
# =====================================
# Rule: good -> clean
# Support: 0.2114098872675809
# Confidence: 0.2114098872675809
# Lift: 1.0
# =====================================
# Rule: great -> clean
# Support: 0.2334195500463618
# Confidence: 0.2334195500463618
# Lift: 1.0
# =====================================
# Rule: help -> clean
# Support: 0.15411644136450148
# Confidence: 0.3822781745551386
# Lift: 1.1807751092567598
# =====================================
# Rule: hotel -> clean
# Support: 0.33058415889902887
# Confidence: 0.33058415889902887
# Lift: 1.0
# =====================================
# Rule: like -> clean
# Support: 0.12717778536918647
# Confidence: 0.315458176976153
# Lift: 1.0838453226724265
# =====================================
# Rule: littl -> clean
# Support: 0.1005319408520814
# Confidence: 0.24936448371867814
# Lift: 1.1602469654585454
# =====================================
# Rule: locat -> clean
# Support: 0.20501683665999706
# Confidence: 0.20501683665999706
# Lift: 1.0
# =====================================
# Rule: love -> clean
# Support: 0.10409448050363575
# Confidence: 0.2582011862970585
# Lift: 1.0400630053888393
# =====================================
# Rule: nice -> clean
# Support: 0.1713435166658533
# Confidence: 0.4250090788040189
# Lift: 1.131314761467024
# =====================================
# Rule: night -> clean
# Support: 0.19008345127128984
# Confidence: 0.47149255538070456
# Lift: 1.0992551999437954
# =====================================
# Rule: place -> clean
# Support: 0.1388902444975843
# Confidence: 0.3445103498365815
# Lift: 1.107698349050901
# =====================================
# Rule: realli -> clean
# Support: 0.10643697232931532
# Confidence: 0.2640116208691442
# Lift: 1.1083511827964831
# =====================================
# Rule: recommend -> clean
# Support: 0.1178078180664682
# Confidence: 0.2922164386878102
# Lift: 1.116295124002968
# =====================================
# Rule: restaur -> clean
# Support: 0.13752379093260456
# Confidence: 0.34112092966953156
# Lift: 1.0957687678097463
# =====================================
# Rule: room -> clean
# Support: 0.3605973354155483
# Confidence: 0.3605973354155483
# Lift: 1.0
# =====================================
# Rule: servic -> clean
# Support: 0.12454248206529696
# Confidence: 0.3089214380825566
# Lift: 0.9752132472268784
# =====================================
# Rule: small -> clean
# Support: 0.11390366502366893
# Confidence: 0.28253238106766737
# Lift: 1.1946700413655742
# =====================================
# Rule: staff -> clean
# Support: 0.24610804743545947
# Confidence: 0.24610804743545947
# Lift: 1.0
# =====================================
# Rule: stay -> clean
# Support: 0.2982284905568298
# Confidence: 0.2982284905568298
# Lift: 1.0
# =====================================
# Rule: time -> clean
# Support: 0.15597091405983116
# Confidence: 0.3868781019247065
# Lift: 1.0825507560479533
# =====================================
# Rule: walk -> clean
# Support: 0.16236396466741496
# Confidence: 0.4027357462776904
# Lift: 1.1794280658819714
# =====================================
# Rule: want -> clean
# Support: 0.1042896881557757
# Confidence: 0.2586853891780656
# Lift: 1.1503303623367496
# =====================================
# Rule: hotel -> close
# Support: 0.14133034014933385
# Confidence: 0.8583283935981031
# Lift: 1.056019640541503
# =====================================
# Rule: room -> close
# Support: 0.14577131423551803
# Confidence: 0.8852993479549496
# Lift: 1.0541384705064136
# =====================================
# Rule: stay -> close
# Support: 0.12444487823922698
# Confidence: 0.7557794902193242
# Lift: 1.0471046338123173
# =====================================
# Rule: room -> come
# Support: 0.11082914450246449
# Confidence: 0.8884976525821595
# Lift: 1.057946737117847
# =====================================
# Rule: great -> comfort
# Support: 0.11658777024059343
# Confidence: 0.5708482676224612
# Lift: 1.0597256615194648
# =====================================
# Rule: hotel -> comfort
# Support: 0.17710214240398223
# Confidence: 0.8671445639187574
# Lift: 1.0668663620089618
# =====================================
# Rule: locat -> comfort
# Support: 0.11380606119759895
# Confidence: 0.5572281959378734
# Lift: 1.197625651663831
# =====================================
# Rule: room -> comfort
# Support: 0.1871065345761554
# Confidence: 0.9161290322580645
# Lift: 1.0908478121912952
# =====================================
# Rule: staff -> comfort
# Support: 0.12298082084817726
# Confidence: 0.6021505376344086
# Lift: 1.0683753283112536
# =====================================
# Rule: stay -> comfort
# Support: 0.1584110097115807
# Confidence: 0.7756272401433693
# Lift: 1.0746029599579296
# =====================================
# Rule: day -> food
# Support: 0.14362403006197844
# Confidence: 0.41316860873227573
# Lift: 1.523800929001631
# =====================================
# Rule: day -> friendli
# Support: 0.10687618954663022
# Confidence: 0.30745472413309
# Lift: 1.0683491185706542
# =====================================
# Rule: day -> good
# Support: 0.18852179005417014
# Confidence: 0.542327670925172
# Lift: 1.19121409635842
# =====================================
# Rule: day -> got
# Support: 0.10731540676394515
# Confidence: 0.3087182366980205
# Lift: 1.5199292138825418
# =====================================
# Rule: day -> great
# Support: 0.2021375237909326
# Confidence: 0.2021375237909326
# Lift: 1.0
# =====================================
# Rule: help -> day
# Support: 0.12312722658728222
# Confidence: 0.3542046890355187
# Lift: 1.0940621469741956
# =====================================
# Rule: day -> hotel
# Support: 0.27685325264750377
# Confidence: 0.27685325264750377
# Lift: 1.0
# =====================================
# Rule: day -> like
# Support: 0.14133034014933385
# Confidence: 0.4065702653376386
# Lift: 1.3968865370612933
# =====================================
# Rule: littl -> day
# Support: 0.10097115806939631
# Confidence: 0.29046749964902424
# Lift: 1.3514917200972199
# =====================================
# Rule: day -> locat
# Support: 0.1432824166707335
# Confidence: 0.41218587673732976
# Lift: 0.8858926788572083
# =====================================
# Rule: day -> love
# Support: 0.10082475233029135
# Confidence: 0.29004632879404746
# Lift: 1.1683387700646406
# =====================================
# Rule: day -> make
# Support: 0.10424088624274072
# Confidence: 0.29987364874350697
# Lift: 1.4749666193958717
# =====================================
# Rule: day -> nice
# Support: 0.1545556585818164
# Confidence: 0.4446160325705461
# Lift: 1.1835057318008653
# =====================================
# Rule: day -> night
# Support: 0.178370992142892
# Confidence: 0.513126491646778
# Lift: 1.1963221003907303
# =====================================
# Rule: day -> peopl
# Support: 0.10799863354643502
# Confidence: 0.3106837006879124
# Lift: 1.5377342296608727
# =====================================
# Rule: day -> place
# Support: 0.1355717144112049
# Confidence: 0.39000421170854976
# Lift: 1.2539740000188127
# =====================================
# Rule: day -> pool
# Support: 0.11932067737055292
# Confidence: 0.343254246806121
# Lift: 1.6169247750124656
# =====================================
# Rule: day -> realli
# Support: 0.11019471963300961
# Confidence: 0.3170012635125649
# Lift: 1.3308078038590385
# =====================================
# Rule: day -> recommend
# Support: 0.10136157337367625
# Confidence: 0.2915906219289625
# Lift: 1.1139044433158782
# =====================================
# Rule: day -> restaur
# Support: 0.14298960519252354
# Confidence: 0.4113435350273761
# Lift: 1.3213419621015776
# =====================================
# Rule: room -> day
# Support: 0.3075008540334781
# Confidence: 0.3075008540334781
# Lift: 1.0
# =====================================
# Rule: day -> servic
# Support: 0.1393294617148992
# Confidence: 0.4008142636529552
# Lift: 1.2653035089374065
# =====================================
# Rule: staff -> day
# Support: 0.20774974378995656
# Confidence: 0.20774974378995656
# Lift: 1.0
# =====================================
# Rule: stay -> day
# Support: 0.2627006978673564
# Confidence: 0.2627006978673564
# Lift: 1.0
# =====================================
# Rule: day -> time
# Support: 0.17290517788297302
# Confidence: 0.49740277972764285
# Lift: 1.391817610186963
# =====================================
# Rule: walk -> day
# Support: 0.14025669806256405
# Confidence: 0.4034816790678085
# Lift: 1.1816125604942782
# =====================================
# Rule: day -> want
# Support: 0.11546532624078863
# Confidence: 0.33216341429173096
# Lift: 1.4770747661136847
# =====================================
# Rule: hotel -> definit
# Support: 0.11409887267580889
# Confidence: 0.8471014492753624
# Lift: 1.0422068926509427
# =====================================
# Rule: room -> definit
# Support: 0.11956468693572789
# Confidence: 0.88768115942029
# Lift: 1.0569745271474904
# =====================================
# Rule: stay -> definit
# Support: 0.11009711580693964
# Confidence: 0.8173913043478261
# Lift: 1.1324655319399124
# =====================================
# Rule: desk -> hotel
# Support: 0.13098433458591577
# Confidence: 0.8392745465916198
# Lift: 1.032577288154241
# =====================================
# Rule: room -> desk
# Support: 0.14357522814894344
# Confidence: 0.9199499687304565
# Lift: 1.095397455357998
# =====================================
# Rule: stay -> desk
# Support: 0.12215118832658241
# Confidence: 0.7826766729205754
# Lift: 1.0843696893046322
# =====================================
# Rule: hotel -> door
# Support: 0.10604655702503538
# Confidence: 0.8541666666666666
# Lift: 1.050899379565696
# =====================================
# Rule: room -> door
# Support: 0.11483090137133375
# Confidence: 0.9249213836477987
# Lift: 1.101316989501252
# =====================================
# Rule: hotel -> drink
# Support: 0.10150797911278123
# Confidence: 0.73008073008073
# Lift: 0.8982338180777087
# =====================================
# Rule: room -> drink
# Support: 0.12239519789175736
# Confidence: 0.8803088803088802
# Lift: 1.0481962500092548
# =====================================
# Rule: stay -> drink
# Support: 0.10253281928651603
# Confidence: 0.7374517374517374
# Lift: 1.0217122077162644
# =====================================
# Rule: eat -> room
# Support: 0.10638817041628032
# Confidence: 0.8989690721649485
# Lift: 1.0704152047028856
# =====================================
# Rule: great -> enjoy
# Support: 0.10570494363379045
# Confidence: 0.6240276577355228
# Lift: 1.158448154979036
# =====================================
# Rule: hotel -> enjoy
# Support: 0.12947147528183106
# Confidence: 0.7643330452319217
# Lift: 0.9403751684087246
# =====================================
# Rule: room -> enjoy
# Support: 0.14582011614855303
# Confidence: 0.8608470181503889
# Lift: 1.0250227351339194
# =====================================
# Rule: staff -> enjoy
# Support: 0.10306964032990093
# Confidence: 0.6084701815038893
# Lift: 1.079588058636782
# =====================================
# Rule: stay -> enjoy
# Support: 0.1345468742374701
# Confidence: 0.794295592048401
# Lift: 1.100467273608099
# =====================================
# Rule: excel -> good
# Support: 0.11849104484895807
# Confidence: 0.5191361984177891
# Lift: 1.1402743961602442
# =====================================
# Rule: excel -> great
# Support: 0.12903225806451613
# Confidence: 0.5653196493478726
# Lift: 1.0494623061050243
# =====================================
# Rule: excel -> hotel
# Support: 0.1887169977063101
# Confidence: 0.8268120590121874
# Lift: 1.0172444251707433
# =====================================
# Rule: excel -> locat
# Support: 0.12381045336977209
# Confidence: 0.5424417361556553
# Lift: 1.1658457746554995
# =====================================
# Rule: excel -> night
# Support: 0.10297203650383095
# Confidence: 0.4511438956596109
# Lift: 1.0518135812903728
# =====================================
# Rule: excel -> room
# Support: 0.19593968083548874
# Confidence: 0.8584562753902074
# Lift: 1.0221760438735976
# =====================================
# Rule: excel -> staff
# Support: 0.14401444536625835
# Confidence: 0.6309600171049818
# Lift: 1.1194910131178617
# =====================================
# Rule: excel -> stay
# Support: 0.16685374066663414
# Confidence: 0.7310241607868292
# Lift: 1.0128070370982363
# =====================================
# Rule: hotel -> expect
# Support: 0.12317602850031721
# Confidence: 0.8107934468358498
# Lift: 0.997536386617436
# =====================================
# Rule: room -> expect
# Support: 0.13640134693279976
# Confidence: 0.8978477353035658
# Lift: 1.0690800130225675
# =====================================
# Rule: stay -> expect
# Support: 0.11331804206724903
# Confidence: 0.7459042724060392
# Lift: 1.0334228834261088
# =====================================
# Rule: hotel -> experi
# Support: 0.11131716363281441
# Confidence: 0.8166845685642677
# Lift: 1.0047843587181273
# =====================================
# Rule: room -> experi
# Support: 0.1167341759796984
# Confidence: 0.8564267812388112
# Lift: 1.019759496447468
# =====================================
# Rule: stay -> experi
# Support: 0.10282563076472598
# Confidence: 0.7543859649122806
# Lift: 1.0451739558497324
# =====================================
# Rule: great -> floor
# Support: 0.10697379337270022
# Confidence: 0.5756302521008404
# Lift: 1.0686029621125495
# =====================================
# Rule: hotel -> floor
# Support: 0.1615343321458201
# Confidence: 0.8692226890756303
# Lift: 1.0694231234973726
# =====================================
# Rule: night -> floor
# Support: 0.10170318676492118
# Confidence: 0.5472689075630253
# Lift: 1.275922992931386
# =====================================
# Rule: room -> floor
# Support: 0.17671172709970231
# Confidence: 0.9508928571428572
# Lift: 1.1322415907789114
# =====================================
# Rule: staff -> floor
# Support: 0.10819384119857499
# Confidence: 0.5821953781512605
# Lift: 1.032969563918736
# =====================================
# Rule: stay -> floor
# Support: 0.14606412571372798
# Confidence: 0.7859768907563026
# Lift: 1.088942019505571
# =====================================
# Rule: good -> food
# Support: 0.16939144014445368
# Confidence: 0.6247300215982722
# Lift: 1.372209547922628
# =====================================
# Rule: great -> food
# Support: 0.17397881996974282
# Confidence: 0.6416486681065515
# Lift: 1.1911598893070616
# =====================================
# Rule: hotel -> food
# Support: 0.19159631057537455
# Confidence: 0.7066234701223902
# Lift: 0.8693738532739657
# =====================================
# Rule: like -> food
# Support: 0.11961348884876287
# Confidence: 0.44114470842332615
# Lift: 1.5156767639675346
# =====================================
# Rule: food -> nice
# Support: 0.12473768971743693
# Confidence: 0.4600431965442765
# Lift: 1.2245706859429424
# =====================================
# Rule: night -> food
# Support: 0.12912986189058612
# Confidence: 0.4762419006479482
# Lift: 1.1103279993374795
# =====================================
# Rule: peopl -> food
# Support: 0.10248401737348103
# Confidence: 0.3779697624190065
# Lift: 1.870767729885957
# =====================================
# Rule: place -> food
# Support: 0.11151237128495436
# Confidence: 0.4112670986321094
# Lift: 1.322340203682811
# =====================================
# Rule: food -> pool
# Support: 0.11975989458786784
# Confidence: 0.44168466522678185
# Lift: 2.080588614979767
# =====================================
# Rule: resort -> food
# Support: 0.1070713971987702
# Confidence: 0.39488840892728583
# Lift: 2.7720652234768806
# =====================================
# Rule: restaur -> food
# Support: 0.13752379093260456
# Confidence: 0.5071994240460763
# Lift: 1.6292559018855857
# =====================================
# Rule: room -> food
# Support: 0.23044263335122736
# Confidence: 0.23044263335122736
# Lift: 1.0
# =====================================
# Rule: servic -> food
# Support: 0.1270313796300815
# Confidence: 0.4685025197984161
# Lift: 1.4789839983345163
# =====================================
# Rule: staff -> food
# Support: 0.16124152066761016
# Confidence: 0.5946724262059035
# Lift: 1.055107168186438
# =====================================
# Rule: stay -> food
# Support: 0.19047386657556975
# Confidence: 0.7024838012958963
# Lift: 0.9732654207136044
# =====================================
# Rule: time -> food
# Support: 0.1433312185837685
# Confidence: 0.5286177105831534
# Lift: 1.4791622979051477
# =====================================
# Rule: walk -> food
# Support: 0.10004392172173149
# Confidence: 0.3689704823614111
# Lift: 1.0805451127722845
# =====================================
# Rule: free -> hotel
# Support: 0.12742179493436143
# Confidence: 0.8515981735159817
# Lift: 1.0477393079265074
# =====================================
# Rule: free -> room
# Support: 0.13547411058513495
# Confidence: 0.9054142204827137
# Lift: 1.078089534075849
# =====================================
# Rule: free -> stay
# Support: 0.1151237128495437
# Confidence: 0.7694063926940639
# Lift: 1.0659842050503083
# =====================================
# Rule: good -> friendli
# Support: 0.1431848128446635
# Confidence: 0.4975411226047142
# Lift: 1.0928411558895057
# =====================================
# Rule: great -> friendli
# Support: 0.17056268605729344
# Confidence: 0.5926742411395625
# Lift: 1.1002435110700104
# =====================================
# Rule: help -> friendli
# Support: 0.13156995754233566
# Confidence: 0.45718161777174837
# Lift: 1.4121357446127367
# =====================================
# Rule: hotel -> friendli
# Support: 0.2368356839588112
# Confidence: 0.2368356839588112
# Lift: 1.0
# =====================================
# Rule: locat -> friendli
# Support: 0.14747938119174273
# Confidence: 0.5124639647278277
# Lift: 1.1014158906270106
# =====================================
# Rule: nice -> friendli
# Support: 0.11444048606705383
# Confidence: 0.3976598270306936
# Lift: 1.0585148760309095
# =====================================
# Rule: night -> friendli
# Support: 0.12888585232541117
# Confidence: 0.4478548414448025
# Lift: 1.0441453585214981
# =====================================
# Rule: restaur -> friendli
# Support: 0.10209360206920111
# Confidence: 0.35475665592674244
# Lift: 1.1395702518568553
# =====================================
# Rule: room -> friendli
# Support: 0.24825533160899907
# Confidence: 0.24825533160899907
# Lift: 1.0
# =====================================
# Rule: staff -> friendli
# Support: 0.23215070030745205
# Confidence: 0.23215070030745205
# Lift: 1.0
# =====================================
# Rule: stay -> friendli
# Support: 0.2156556537016251
# Confidence: 0.2156556537016251
# Lift: 1.0
# =====================================
# Rule: time -> friendli
# Support: 0.11097555024156947
# Confidence: 0.3856198066813634
# Lift: 1.0790298318595954
# =====================================
# Rule: walk -> friendli
# Support: 0.11102435215460446
# Confidence: 0.38578938443276245
# Lift: 1.129799953753285
# =====================================
# Rule: room -> go
# Support: 0.11053633302425456
# Confidence: 0.8671516079632465
# Lift: 1.032529699504613
# =====================================
# Rule: good -> got
# Support: 0.11917427163144795
# Confidence: 0.261764390609926
# Lift: 1.2887588005737611
# =====================================
# Rule: great -> good
# Support: 0.25874774291152214
# Confidence: 0.25874774291152214
# Lift: 1.0
# =====================================
# Rule: help -> good
# Support: 0.1562149236250061
# Confidence: 0.34312359309679497
# Lift: 1.0598350235372966
# =====================================
# Rule: hotel -> good
# Support: 0.3692352740227417
# Confidence: 0.3692352740227417
# Lift: 1.0
# =====================================
# Rule: like -> good
# Support: 0.1614855302327851
# Confidence: 0.354700396612713
# Lift: 1.2186730092205067
# =====================================
# Rule: littl -> good
# Support: 0.12185837684837246
# Confidence: 0.2676599849930325
# Lift: 1.2453725596031402
# =====================================
# Rule: good -> locat
# Support: 0.22307354448294373
# Confidence: 0.22307354448294373
# Lift: 1.0
# =====================================
# Rule: look -> good
# Support: 0.11775901615343322
# Confidence: 0.25865580448065173
# Lift: 1.2175777830491694
# =====================================
# Rule: lot -> good
# Support: 0.10604655702503538
# Confidence: 0.23292957444527815
# Lift: 1.3547998609021275
# =====================================
# Rule: love -> good
# Support: 0.11214679615440926
# Confidence: 0.2463286525887019
# Lift: 0.9922391232937077
# =====================================
# Rule: make -> good
# Support: 0.1124396076326192
# Confidence: 0.24697180833958626
# Lift: 1.2147621998767313
# =====================================
# Rule: minut -> good
# Support: 0.10507051876433557
# Confidence: 0.23078572194233038
# Lift: 1.197526013755455
# =====================================
# Rule: good -> need
# Support: 0.10458249963398565
# Confidence: 0.22971379569085645
# Lift: 1.2035452282028483
# =====================================
# Rule: good -> nice
# Support: 0.20516324239910205
# Confidence: 0.20516324239910205
# Lift: 1.0
# =====================================
# Rule: night -> good
# Support: 0.21941340100531942
# Confidence: 0.21941340100531942
# Lift: 1.0
# =====================================
# Rule: peopl -> good
# Support: 0.11990630032697282
# Confidence: 0.26337227998713686
# Lift: 1.3035655529508265
# =====================================
# Rule: place -> good
# Support: 0.15855741545068566
# Confidence: 0.34826883910386963
# Lift: 1.1197829565475275
# =====================================
# Rule: good -> pool
# Support: 0.12673856815187157
# Confidence: 0.2783792475077715
# Lift: 1.311326243834884
# =====================================
# Rule: price -> good
# Support: 0.11082914450246449
# Confidence: 0.24343445170972236
# Lift: 1.2045919705346344
# =====================================
# Rule: good -> realli
# Support: 0.13605973354155482
# Confidence: 0.2988530389109229
# Lift: 1.2546194673885926
# =====================================
# Rule: recommend -> good
# Support: 0.12600653945634668
# Confidence: 0.2767713581305606
# Lift: 1.0572934189883143
# =====================================
# Rule: restaur -> good
# Support: 0.17881020936020692
# Confidence: 0.39275377854003646
# Lift: 1.2616268499865007
# =====================================
# Rule: good -> review
# Support: 0.10834024693767996
# Confidence: 0.2379676278272055
# Lift: 1.2075766869260198
# =====================================
# Rule: room -> good
# Support: 0.4007125079303109
# Confidence: 0.4007125079303109
# Lift: 1.0
# =====================================
# Rule: servic -> good
# Support: 0.16241276658044995
# Confidence: 0.35673705649051346
# Lift: 1.1261591472110786
# =====================================
# Rule: small -> good
# Support: 0.12537211458689182
# Confidence: 0.27537785400364456
# Lift: 1.1644175828288652
# =====================================
# Rule: staff -> good
# Support: 0.2621150749109365
# Confidence: 0.2621150749109365
# Lift: 1.0
# =====================================
# Rule: stay -> good
# Support: 0.3286808842906642
# Confidence: 0.3286808842906642
# Lift: 1.0
# =====================================
# Rule: thing -> good
# Support: 0.10228880972134108
# Confidence: 0.22467574230892914
# Lift: 1.3383228592012404
# =====================================
# Rule: good -> time
# Support: 0.1914011029232346
# Confidence: 0.42040947582806304
# Lift: 1.1763772455541226
# =====================================
# Rule: good -> trip
# Support: 0.10150797911278123
# Confidence: 0.2229606603065709
# Lift: 1.1857479601198921
# =====================================
# Rule: use -> good
# Support: 0.10848665267678494
# Confidence: 0.23828920570264767
# Lift: 1.2762112164278498
# =====================================
# Rule: view -> good
# Support: 0.1032648479820409
# Confidence: 0.22681959481187694
# Lift: 1.1000616135598036
# =====================================
# Rule: walk -> good
# Support: 0.1832511834463911
# Confidence: 0.40250830742844895
# Lift: 1.1787620019317346
# =====================================
# Rule: good -> want
# Support: 0.1275682006734664
# Confidence: 0.28020152213527705
# Lift: 1.2460089822209117
# =====================================
# Rule: great -> got
# Support: 0.12302962276121224
# Confidence: 0.6057184046131667
# Lift: 1.1244587632658452
# =====================================
# Rule: hotel -> got
# Support: 0.1583622077985457
# Confidence: 0.7796732340221048
# Lift: 0.9592485282706064
# =====================================
# Rule: night -> got
# Support: 0.11151237128495436
# Confidence: 0.5490148966842864
# Lift: 1.2799936566114134
# =====================================
# Rule: room -> got
# Support: 0.18227514518569127
# Confidence: 0.8974050937049495
# Lift: 1.0685529534027614
# =====================================
# Rule: staff -> got
# Support: 0.11527011858864868
# Confidence: 0.5675156174915906
# Lift: 1.006923761193193
# =====================================
# Rule: stay -> got
# Support: 0.15074910936508712
# Confidence: 0.7421912542047093
# Lift: 1.0282786335299998
# =====================================
# Rule: got -> time
# Support: 0.10736420867698014
# Confidence: 0.5285920230658337
# Lift: 1.4790904198609858
# =====================================
# Rule: help -> great
# Support: 0.1887657996193451
# Confidence: 0.350425801775684
# Lift: 1.0823899765127436
# =====================================
# Rule: great -> hotel
# Support: 0.43238494949002
# Confidence: 0.43238494949002
# Lift: 1.0
# =====================================
# Rule: like -> great
# Support: 0.17114830901371333
# Confidence: 0.3177206015582533
# Lift: 1.0916185188682375
# =====================================
# Rule: littl -> great
# Support: 0.13547411058513495
# Confidence: 0.2514948360210183
# Lift: 1.1701591019315818
# =====================================
# Rule: great -> locat
# Support: 0.2832463032550876
# Confidence: 0.2832463032550876
# Lift: 1.0
# =====================================
# Rule: great -> look
# Support: 0.1248352935435069
# Confidence: 0.23174488131907955
# Lift: 1.090899233427351
# =====================================
# Rule: lot -> great
# Support: 0.11073154067639451
# Confidence: 0.2055626019206378
# Lift: 1.1956239784149274
# =====================================
# Rule: love -> great
# Support: 0.15323800692987166
# Confidence: 0.28447182460590686
# Lift: 1.145884049144808
# =====================================
# Rule: great -> make
# Support: 0.11995510224000781
# Confidence: 0.2226852690704838
# Lift: 1.0953057725691993
# =====================================
# Rule: minut -> great
# Support: 0.1124396076326192
# Confidence: 0.20873346620764632
# Lift: 1.0830988746672274
# =====================================
# Rule: great -> need
# Support: 0.11312283441510908
# Confidence: 0.21000181192244974
# Lift: 1.1002677392234512
# =====================================
# Rule: great -> nice
# Support: 0.2232687521350837
# Confidence: 0.2232687521350837
# Lift: 1.0
# =====================================
# Rule: night -> great
# Support: 0.24239910204480017
# Confidence: 0.24239910204480017
# Lift: 1.0
# =====================================
# Rule: great -> peopl
# Support: 0.12449368015226196
# Confidence: 0.23111070846167783
# Lift: 1.143886359200058
# =====================================
# Rule: place -> great
# Support: 0.18842418622810014
# Confidence: 0.3497916289182823
# Lift: 1.1246791570947
# =====================================
# Rule: great -> pool
# Support: 0.1356693182372749
# Confidence: 0.25185722051096215
# Lift: 1.186392254135661
# =====================================
# Rule: price -> great
# Support: 0.11649016641452345
# Confidence: 0.2162529443739808
# Lift: 1.0700891289947454
# =====================================
# Rule: great -> realli
# Support: 0.15084671319115708
# Confidence: 0.28003261460409495
# Lift: 1.1756091591584736
# =====================================
# Rule: great -> recommend
# Support: 0.15601971597286612
# Confidence: 0.28963580358760643
# Lift: 1.1064368477467643
# =====================================
# Rule: great -> restaur
# Support: 0.19579327509638378
# Confidence: 0.3634716434136619
# Lift: 1.1675650486266416
# =====================================
# Rule: great -> return
# Support: 0.10121516763457128
# Confidence: 0.5677525321653436
# Lift: 1.0539787222866512
# =====================================
# Rule: great -> review
# Support: 0.11771021424039822
# Confidence: 0.21851784743612973
# Lift: 1.1088779623114746
# =====================================
# Rule: right -> great
# Support: 0.10180079059099116
# Confidence: 0.6277460126391814
# Lift: 1.1653509281563206
# =====================================
# Rule: room -> great
# Support: 0.4578107461812503
# Confidence: 0.4578107461812503
# Lift: 1.0
# =====================================
# Rule: servic -> great
# Support: 0.1831535796203211
# Confidence: 0.34000724768979884
# Lift: 1.0733459424451808
# =====================================
# Rule: small -> great
# Support: 0.13332682641159532
# Confidence: 0.24750860663163615
# Lift: 1.046574258870998
# =====================================
# Rule: staff -> great
# Support: 0.3177004538577912
# Confidence: 0.3177004538577912
# Lift: 1.0
# =====================================
# Rule: stay -> great
# Support: 0.3969059587135816
# Confidence: 0.3969059587135816
# Lift: 1.0
# =====================================
# Rule: great -> thing
# Support: 0.10287443267776097
# Confidence: 0.6127906976744186
# Lift: 1.1375878044977814
# =====================================
# Rule: great -> time
# Support: 0.2141427943975404
# Confidence: 0.2141427943975404
# Lift: 1.0
# =====================================
# Rule: great -> trip
# Support: 0.11790542189253819
# Confidence: 0.2188802319260736
# Lift: 1.1640474519587787
# =====================================
# Rule: great -> use
# Support: 0.11014591771997462
# Confidence: 0.20447544845080629
# Lift: 1.0951140653960982
# =====================================
# Rule: view -> great
# Support: 0.12600653945634668
# Confidence: 0.23391918825874253
# ...
# Confidence: 0.3483968571568005
# Lift: 1.0
# =====================================
# Rule: night -> time
# Support: 0.17671172709970231
# Confidence: 0.4119922630560929
# Lift: 1.1528244520391095
# =====================================
# Rule: view -> night
# Support: 0.10350885754721585
# Confidence: 0.24132438275116624
# Lift: 1.170408976793881
# =====================================
# Rule: walk -> night
# Support: 0.17227075301351813
# Confidence: 0.4016384116509273
# Lift: 1.1762144766527298
# =====================================
# Rule: night -> want
# Support: 0.11971109267483285
# Confidence: 0.27909887359199
# Lift: 1.2411056898379917
# =====================================
# Rule: room -> open
# Support: 0.10101995998243131
# Confidence: 0.9216384683882458
# Lift: 1.0974079758117
# =====================================
# Rule: room -> peopl
# Support: 0.17529647162168757
# Confidence: 0.8676328502415459
# Lift: 1.0331027215003497
# =====================================
# Rule: staff -> peopl
# Support: 0.11263481528475916
# Confidence: 0.557487922705314
# Lift: 0.9891319615684986
# =====================================
# Rule: stay -> peopl
# Support: 0.14572251232248304
# Confidence: 0.721256038647343
# Lift: 0.9992736638216839
# =====================================
# Rule: peopl -> time
# Support: 0.11273241911082914
# Confidence: 0.5579710144927535
# Lift: 1.5612978366749983
# =====================================
# Rule: place -> restaur
# Support: 0.11683177980576838
# Confidence: 0.3756472618860819
# Lift: 1.2066762883379376
# =====================================
# Rule: room -> place
# Support: 0.26499438778000095
# Confidence: 0.26499438778000095
# Lift: 1.0
# =====================================
# Rule: place -> servic
# Support: 0.1075594163291201
# Confidence: 0.3458339871332182
# Lift: 1.0917399831068826
# =====================================
# Rule: staff -> place
# Support: 0.17705334049094726
# Confidence: 0.5692766358073121
# Lift: 1.010048276415935
# =====================================
# Rule: stay -> place
# Support: 0.23795812795861598
# Confidence: 0.23795812795861598
# Lift: 1.0
# =====================================
# Rule: place -> time
# Support: 0.13698696988921966
# Confidence: 0.44045190648046445
# Lift: 1.2324593767159904
# =====================================
# Rule: walk -> place
# Support: 0.12249280171782734
# Confidence: 0.39384905068256704
# Lift: 1.1534030152260228
# =====================================
# Rule: restaur -> pool
# Support: 0.1059001512859304
# Confidence: 0.4988505747126436
# Lift: 1.6024372356853396
# =====================================
# Rule: room -> pool
# Support: 0.1848616465765458
# Confidence: 0.8708045977011494
# Lift: 1.036879366116233
# =====================================
# Rule: staff -> pool
# Support: 0.12298082084817726
# Confidence: 0.5793103448275863
# Lift: 1.0278507468925508
# =====================================
# Rule: stay -> pool
# Support: 0.15309160119076667
# Confidence: 0.7211494252873563
# Lift: 0.9991259549400416
# =====================================
# Rule: time -> pool
# Support: 0.11380606119759895
# Confidence: 0.5360919540229885
# Lift: 1.500076502783703
# =====================================
# Rule: price -> room
# Support: 0.18017666292518666
# Confidence: 0.8915720840376721
# Lift: 1.0616075061895485
# =====================================
# Rule: price -> staff
# Support: 0.11185398467619931
# Confidence: 0.5534894952909926
# Lift: 0.9820376870731431
# =====================================
# Rule: price -> stay
# Support: 0.15231077058220682
# Confidence: 0.7536826853417049
# Lift: 1.044199587920005
# =====================================
# Rule: room -> problem
# Support: 0.14025669806256405
# Confidence: 0.9069106973808773
# Lift: 1.0798714103103932
# =====================================
# Rule: stay -> problem
# Support: 0.11634376067541848
# Confidence: 0.7522877879457243
# Lift: 1.0422670089787582
# =====================================
# Rule: room -> quiet
# Support: 0.11034112537211459
# Confidence: 0.9164977705715445
# Lift: 1.091286874122931
# =====================================
# Rule: quit -> room
# Support: 0.12078473476160266
# Confidence: 0.9142962689323975
# Lift: 1.088665514945305
# =====================================
# Rule: quit -> stay
# Support: 0.10082475233029135
# Confidence: 0.7632065016623569
# Lift: 1.0573944844870422
# =====================================
# Rule: room -> realli
# Support: 0.210824264311161
# Confidence: 0.210824264311161
# Lift: 1.0
# =====================================
# Rule: staff -> realli
# Support: 0.14089112293201894
# Confidence: 0.5914771563204262
# Lift: 1.0494379089238768
# =====================================
# Rule: stay -> realli
# Support: 0.18037187057732662
# Confidence: 0.7572218807621388
# Lift: 1.0491030127584169
# =====================================
# Rule: time -> realli
# Support: 0.11590454345810355
# Confidence: 0.48658061872567093
# Lift: 1.3615353623252386
# =====================================
# Rule: restaur -> recommend
# Support: 0.10419208432970573
# Confidence: 0.3980238627889635
# Lift: 1.2785557254128628
# =====================================
# Rule: room -> recommend
# Support: 0.22629447074325312
# Confidence: 0.22629447074325312
# Lift: 1.0
# =====================================
# Rule: staff -> recommend
# Support: 0.16202235127617
# Confidence: 0.6189410887397464
# Lift: 1.0981662351169923
# =====================================
# Rule: stay -> recommend
# Support: 0.19984383387828802
# Confidence: 0.7634228187919464
# Lift: 1.0576941838989704
# =====================================
# Rule: recommend -> time
# Support: 0.1032648479820409
# Confidence: 0.3944817300521999
# Lift: 1.1038270012972318
# =====================================
# Rule: walk -> recommend
# Support: 0.10790102972036504
# Confidence: 0.41219239373601796
# Lift: 1.2071222438251743
# =====================================
# Rule: room -> resort
# Support: 0.11585574154506857
# Confidence: 0.8132922233641658
# Lift: 0.9683985675492546
# =====================================
# Rule: room -> restaur
# Support: 0.27343711873505444
# Confidence: 0.27343711873505444
# Lift: 1.0
# =====================================
# Rule: servic -> restaur
# Support: 0.12878824849934117
# Confidence: 0.41370120708575014
# Lift: 1.3059854312731638
# =====================================
# Rule: staff -> restaur
# Support: 0.18793616709775024
# Confidence: 0.6036996394419188
# Lift: 1.071123847242563
# =====================================
# Rule: stay -> restaur
# Support: 0.23117466204675224
# Confidence: 0.23117466204675224
# Lift: 1.0
# =====================================
# Rule: restaur -> time
# Support: 0.14093992484505394
# Confidence: 0.4527355384856561
# Lift: 1.2668310691123281
# =====================================
# Rule: walk -> restaur
# Support: 0.14040310380166904
# Confidence: 0.45101113027120243
# Lift: 1.3208044976971858
# =====================================
# Rule: room -> return
# Support: 0.15196915719096188
# Confidence: 0.8524500410621407
# Lift: 1.0150243356037147
# =====================================
# Rule: staff -> return
# Support: 0.11419647650187888
# Confidence: 0.6405693950177936
# Lift: 1.1365406072655304
# =====================================
# Rule: stay -> return
# Support: 0.13444927041140012
# Confidence: 0.7541746509718039
# Lift: 1.0448811881719562
# =====================================
# Rule: room -> review
# Support: 0.17363720657849788
# Confidence: 0.8811292719167906
# Lift: 1.049173101914519
# =====================================
# Rule: staff -> review
# Support: 0.11995510224000781
# Confidence: 0.6087171867261021
# Lift: 1.0800263116464248
# =====================================
# Rule: stay -> review
# Support: 0.14977307110438728
# Confidence: 0.7600297176820208
# Lift: 1.052993167344306
# =====================================
# Rule: right -> room
# Support: 0.145917719974623
# Confidence: 0.8997893469756244
# Lift: 1.0713919175360287
# =====================================
# Rule: right -> stay
# Support: 0.12464008589136694
# Confidence: 0.7685826060788444
# Lift: 1.0648428790508182
# =====================================
# Rule: room -> say
# Support: 0.13913425406275925
# Confidence: 0.8764217645250538
# Lift: 1.043567806199249
# =====================================
# Rule: room -> servic
# Support: 0.2784637157776585
# Confidence: 0.2784637157776585
# Lift: 1.0
# =====================================
# Rule: room -> shop
# Support: 0.12742179493436143
# Confidence: 0.8862864901561439
# Lift: 1.0553138747044886
# =====================================
# Rule: room -> shower
# Support: 0.11629495876238348
# Confidence: 0.9490242931103146
# Lift: 1.1300166651242638
# =====================================
# Rule: room -> small
# Support: 0.22165828900492898
# Confidence: 0.22165828900492898
# Lift: 1.0
# =====================================
# Rule: room -> staff
# Support: 0.4842613830462154
# Confidence: 0.4842613830462154
# Lift: 1.0
# =====================================
# Rule: room -> stay
# Support: 0.6208091357181201
# Confidence: 0.6208091357181201
# Lift: 1.0
# =====================================
# Rule: room -> street
# Support: 0.1345956761505051
# Confidence: 0.9105315285572797
# Lift: 1.0841827852674308
# =====================================
# Rule: room -> thing
# Support: 0.15065150553901713
# Confidence: 0.8973837209302326
# Lift: 1.0685275045372418
# =====================================
# Rule: room -> think
# Support: 0.11165877702405934
# Confidence: 0.9004329004329004
# Lift: 1.072158205751093
# =====================================
# Rule: room -> time
# Support: 0.3113074032502074
# Confidence: 0.3113074032502074
# Lift: 1.0
# =====================================
# Rule: room -> travel
# Support: 0.13918305597579425
# Confidence: 0.8753836709637814
# Lift: 1.042331733495197
# =====================================
# Rule: room -> tri
# Support: 0.14089112293201894
# Confidence: 0.894361833952912
# Lift: 1.0649293009198164
# =====================================
# Rule: room -> trip
# Support: 0.16221755892831
# Confidence: 0.8627043861925773
# Lift: 1.0272343295643036
# =====================================
# Rule: room -> use
# Support: 0.17114830901371333
# Confidence: 0.20378871520715905
# Lift: 1.0914361116858067
# =====================================
# Rule: room -> view
# Support: 0.1918891220535845
# Confidence: 0.22848509500842581
# Lift: 1.1081391909627583
# =====================================
# Rule: room -> visit
# Support: 0.10677858572056025
# Confidence: 0.8523568367744448
# Lift: 1.014913355938471
# =====================================
# Rule: room -> walk
# Support: 0.30276706846908397
# Confidence: 0.30276706846908397
# Lift: 1.0
# =====================================
# Rule: room -> want
# Support: 0.19642769996583867
# Confidence: 0.23388924400023245
# Lift: 1.0400660804706516
# =====================================
# Rule: room -> water
# Support: 0.13488848762871505
# Confidence: 0.8936307791787909
# Lift: 1.0640588236476614
# =====================================
# Rule: room -> way
# Support: 0.14240398223610365
# Confidence: 0.8797105818510702
# Lift: 1.0474838475629193
# =====================================
# Rule: room -> week
# Support: 0.10609535893807037
# Confidence: 0.8442718446601942
# Lift: 1.0052864413348852
# =====================================
# Rule: room -> went
# Support: 0.13654775267190475
# Confidence: 0.8801509908776345
# Lift: 1.0480082488275675
# =====================================
# Rule: room -> wonder
# Support: 0.13801181006295446
# Confidence: 0.8472139005392451
# Lift: 1.0087895889330973
# =====================================
# Rule: room -> work
# Support: 0.1329852130203504
# Confidence: 0.9086362120706902
# Lift: 1.081926005086903
# =====================================
# Rule: stay -> say
# Support: 0.12063832902249769
# Confidence: 0.759913925607132
# Lift: 1.0528327416913956
# =====================================
# Rule: staff -> servic
# Support: 0.16929383631838368
# Confidence: 0.5344322908642737
# Lift: 0.9482251339596357
# =====================================
# Rule: stay -> servic
# Support: 0.23756771265433604
# Confidence: 0.23756771265433604
# Lift: 1.0
# =====================================
# Rule: servic -> time
# Support: 0.1411351324971939
# Confidence: 0.44553997843167464
# Lift: 1.2466966677650477
# =====================================
# Rule: walk -> servic
# Support: 0.10946269093748474
# Confidence: 0.3455553843783701
# Lift: 1.0119730429179907
# =====================================
# Rule: stay -> shop
# Support: 0.11068273876335952
# Confidence: 0.769857433808554
# Lift: 1.0666091058939202
# =====================================
# Rule: staff -> small
# Support: 0.1373773851934996
# Confidence: 0.5808914568716468
# Lift: 1.0306560605036725
# =====================================
# Rule: stay -> small
# Support: 0.178419794055927
# Confidence: 0.754436648782501
# Lift: 1.0452441764842615
# =====================================
# Rule: walk -> small
# Support: 0.10184959250402616
# Confidence: 0.4306644655385885
# Lift: 1.2612184598186675
# =====================================
# Rule: staff -> stay
# Support: 0.41964765018788736
# Confidence: 0.41964765018788736
# Lift: 1.0
# =====================================
# Rule: staff -> time
# Support: 0.20901859352886634
# Confidence: 0.20901859352886634
# Lift: 1.0
# =====================================
# Rule: staff -> trip
# Support: 0.11239080571958421
# Confidence: 0.5977160654035817
# Lift: 1.0605073942492678
# =====================================
# Rule: staff -> use
# Support: 0.10941388902444976
# Confidence: 0.5859905906952431
# Lift: 1.0397032811443612
# =====================================
# Rule: staff -> view
# Support: 0.11849104484895807
# Confidence: 0.2102346523508529
# Lift: 1.019625623981379
# =====================================
# Rule: staff -> walk
# Support: 0.20067346639988287
# Confidence: 0.20067346639988287
# Lift: 1.0
# =====================================
# Rule: staff -> want
# Support: 0.13205797667268557
# Confidence: 0.23430600051952552
# Lift: 1.0419193265289926
# =====================================
# Rule: staff -> wonder
# Support: 0.10614416085110537
# Confidence: 0.6515877771120432
# Lift: 1.1560901498660385
# =====================================
# Rule: stay -> street
# Support: 0.1151725147625787
# Confidence: 0.7791350280620668
# Lift: 1.0794628708600278
# =====================================
# Rule: stay -> thing
# Support: 0.12512810502171684
# Confidence: 0.7453488372093022
# Lift: 1.0326533484283849
# =====================================
# Rule: stay -> time
# Support: 0.27270509003952953
# Confidence: 0.27270509003952953
# Lift: 1.0
# =====================================
# Rule: stay -> travel
# Support: 0.12044312137035772
# Confidence: 0.7575199508901166
# Lift: 1.0495159779370777
# =====================================
# Rule: stay -> tri
# Support: 0.11849104484895807
# Confidence: 0.752168525402726
# Lift: 1.0421017751201662
# =====================================
# Rule: stay -> trip
# Support: 0.14079351910594895
# Confidence: 0.7487671943939788
# Lift: 1.0373893563439498
# =====================================
# Rule: stay -> use
# Support: 0.14338002049680348
# Confidence: 0.7679038159958181
# Lift: 1.0639024404036719
# =====================================
# Rule: stay -> view
# Support: 0.1599238690156654
# Confidence: 0.22156862745098038
# Lift: 1.074594732567583
# =====================================
# Rule: stay -> walk
# Support: 0.2602606022156069
# Confidence: 0.2602606022156069
# Lift: 1.0
# =====================================
# Rule: stay -> want
# Support: 0.17212434727441317
# Confidence: 0.23847194050033807
# Lift: 1.060444560067801
# =====================================
# Rule: stay -> water
# Support: 0.11195158850226929
# Confidence: 0.7416747494342063
# Lift: 1.0275630352032672
# =====================================
# Rule: stay -> way
# Support: 0.12327363232638719
# Confidence: 0.7615315043714199
# Lift: 1.0550738374627968
# =====================================
# Rule: stay -> went
# Support: 0.11326924015421405
# Confidence: 0.7301038062283737
# Lift: 1.0115319197718462
# =====================================
# Rule: stay -> wonder
# Support: 0.12200478258747743
# Confidence: 0.7489514679448772
# Lift: 1.0376446605583827
# =====================================
# Rule: stay -> work
# Support: 0.11073154067639451
# Confidence: 0.7565855285095031
# Lift: 1.0482213701614758
# =====================================
# Rule: walk -> time
# Support: 0.13688936606314966
# Confidence: 0.38303973781237194
# Lift: 1.1217475014310867
# =====================================
# Rule: time -> want
# Support: 0.1172709970230833
# Confidence: 0.3281442031954117
# Lift: 1.459202011214666
# =====================================

# %% [markdown]
# #### So here if we take the rule one
# #### Rule: breakfast -> area
# #### Support: 0.10253281928651603
# #### Confidence: 0.4439983093829248
# #### Lift: 1.236137140973575
#
# #### this says that the word "area" and "breakfast" frequently coming together. The confidence here is 0.44 which says that out of 100% of the time where the words breakfast comes 44% of the time the word "area" comes after it.

# %%
print(rule_len_2)
# Out:
# 619

# %%
y_axis =range(619)
x_axis = list_of_confidence

# %%
plt.figure(figsize=(14, 6))
plt.plot(x_axis,y_axis, )
plt.title('Rule vs Confidence')
plt.xlabel('Confidence')
plt.ylabel('Rule Count')
plt.show()

# %%
y_axis =range(619)
x_axis = list_of_support
plt.figure(figsize=(14, 6))
plt.plot(x_axis,y_axis, )
plt.title('Rule vs Confidenct')
plt.xlabel('Confidence')
plt.ylabel('Rule Count')
plt.show()
